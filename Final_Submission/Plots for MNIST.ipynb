# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
## These results have been copied from the DISTIL_MNIST.ipynbb notebook

rs1 = np.array([0.4801, 0.8442, 0.9042, 0.912 , 0.9263, 0.9075, 0.9296, 0.9212,
       0.9459, 0.9455, 0.9566, 0.9571, 0.9574, 0.947 , 0.973 , 0.965 ,
       0.9669, 0.9721, 0.9635, 0.9673, 0.9686, 0.9694, 0.9699, 0.9772,
       0.9653])
rs2 = np.array([0.5812, 0.8106, 0.8067, 0.8987, 0.9328, 0.9333, 0.9406, 0.94  ,
       0.9594, 0.9362, 0.9506, 0.9647, 0.944 , 0.9613, 0.9481, 0.967 ,
       0.9684, 0.9675, 0.9739, 0.9595, 0.9802, 0.9775, 0.9811, 0.9514,
       0.9752])

rs = (rs1 + rs2)/2


entropy1 = np.array([0.4801, 0.7653, 0.8514, 0.9064, 0.9012, 0.9514, 0.946 , 0.9637,
       0.9748, 0.9737, 0.981 , 0.981 , 0.9806, 0.9769, 0.987 , 0.9853,
       0.9847, 0.9883, 0.9902, 0.9896, 0.9924, 0.9906, 0.9908, 0.9891,
       0.9922])
entropy2 = np.array([0.5812, 0.695 , 0.8741, 0.9137, 0.9312, 0.9571, 0.9723, 0.9719,
       0.9806, 0.9804, 0.9807, 0.9821, 0.9828, 0.9879, 0.9852, 0.9879,
       0.9885, 0.9874, 0.9904, 0.99  , 0.9886, 0.9919, 0.9899, 0.9915,
       0.9925])

entropy = (entropy1 + entropy2)/2


glister1 = np.array([0.4801, 0.711 , 0.8609, 0.892 , 0.9141, 0.9335, 0.9075, 0.9387,
       0.9607, 0.9672, 0.9705, 0.9707, 0.9748, 0.9841, 0.9853, 0.9865,
       0.9852, 0.9886, 0.9839, 0.9883, 0.9831, 0.9902, 0.9886, 0.9903,
       0.9906])
glister2 = np.array([0.5812, 0.7658, 0.7502, 0.8098, 0.823 , 0.8854, 0.9035, 0.9392,
       0.9472, 0.957 , 0.9711, 0.9715, 0.9687, 0.9759, 0.9782, 0.9823,
       0.9814, 0.9844, 0.983 , 0.987 , 0.9888, 0.9863, 0.9845, 0.9894,
       0.9916])

glister = (glister1 + glister2)/2


fass1 = np.array([0.4801, 0.7241, 0.8847, 0.9207, 0.947 , 0.9574, 0.9588, 0.9787,
       0.9806, 0.9824, 0.9854, 0.9808, 0.9823, 0.9869, 0.9905, 0.9895,
       0.985 , 0.992 , 0.9895, 0.9909, 0.9903, 0.991 , 0.9925, 0.9933,
       0.9921])
fass2 = np.array([0.5812, 0.8602, 0.9164, 0.9497, 0.9498, 0.9534, 0.9664, 0.9774,
       0.9789, 0.976 , 0.9816, 0.9791, 0.9803, 0.9673, 0.9847, 0.989 ,
       0.9875, 0.9896, 0.9884, 0.9912, 0.9929, 0.9923, 0.9926, 0.9926,
       0.9921])

fass = (fass1 + fass2)/2


badge1 = np.array([0.4801, 0.7903, 0.8702, 0.9233, 0.9551, 0.9625, 0.97  , 0.969 ,
       0.9797, 0.9773, 0.9843, 0.9859, 0.9848, 0.9851, 0.9863, 0.9886,
       0.9899, 0.9905, 0.9905, 0.9922, 0.9911, 0.9936, 0.9938, 0.9921,
       0.9935])
badge2 = np.array([0.5812, 0.6999, 0.8793, 0.8891, 0.9366, 0.9369, 0.9665, 0.9677,
       0.9765, 0.9829, 0.9799, 0.9852, 0.9875, 0.9885, 0.9868, 0.9849,
       0.9907, 0.9903, 0.9893, 0.9912, 0.9851, 0.9935, 0.9905, 0.9915,
       0.9937])

badge = (badge1 + badge2)/2


coreset1 = np.array([0.4801, 0.8509, 0.8868, 0.8251, 0.9111, 0.9544, 0.9549, 0.9559,
       0.9689, 0.9697, 0.9766, 0.9748, 0.9733, 0.9825, 0.9822, 0.9815,
       0.9859, 0.9865, 0.9831, 0.9856, 0.9798, 0.9852, 0.9856, 0.9761,
       0.9845])
coreset2 = np.array([0.5812, 0.7892, 0.7862, 0.8928, 0.9131, 0.9552, 0.948 , 0.961 ,
       0.9547, 0.9682, 0.9593, 0.9766, 0.9799, 0.9725, 0.9797, 0.9765,
       0.9813, 0.9738, 0.9807, 0.9847, 0.9879, 0.9844, 0.9872, 0.9832,
       0.9811])

coreset = (coreset1 + coreset2)/2


lc1 = np.array([0.4801, 0.5755, 0.8998, 0.8661, 0.9084, 0.9631, 0.95  , 0.9771,
       0.9801, 0.9784, 0.9832, 0.9874, 0.9881, 0.99  , 0.9868, 0.9906,
       0.9912, 0.9905, 0.9921, 0.9901, 0.9904, 0.9927, 0.9916, 0.9917,
       0.9938])
lc2 = np.array([0.5812, 0.8079, 0.7229, 0.9335, 0.9359, 0.9556, 0.9607, 0.9722,
       0.9822, 0.9794, 0.9852, 0.9813, 0.9865, 0.9903, 0.9893, 0.9912,
       0.9916, 0.9927, 0.99  , 0.9911, 0.9908, 0.9918, 0.9918, 0.9928,
       0.9925])

lc = (lc1 + lc2)/2


margin1 = np.array([0.4801, 0.8772, 0.8845, 0.94  , 0.9353, 0.9506, 0.961 , 0.9724,
       0.9788, 0.9788, 0.9801, 0.9849, 0.9871, 0.9811, 0.9873, 0.9885,
       0.9905, 0.9885, 0.9868, 0.9908, 0.9892, 0.9883, 0.9905, 0.9911,
       0.9927])
margin2 = np.array([0.5812, 0.8156, 0.6596, 0.9149, 0.9256, 0.9655, 0.9678, 0.9553,
       0.9749, 0.9797, 0.9843, 0.9834, 0.9863, 0.9876, 0.9832, 0.9879,
       0.9888, 0.9909, 0.9906, 0.9914, 0.9927, 0.9927, 0.9911, 0.9935,
       0.9932])

margin = (margin1 + margin2)/2

train_set_size = np.arange(50, 1300, 50)

# %%
plt.figure(figsize=(15, 10))
plt.plot(train_set_size, rs, label='Random Sampling', linewidth=4)
plt.plot(train_set_size, entropy, label='Entropy', linewidth=4)
# plt.plot(train_set_size, glister, label='Glister')
plt.plot(train_set_size, fass, label='FASS', linewidth=4)
plt.plot(train_set_size, badge, label='BADGE', linewidth=4)
plt.plot(train_set_size, coreset, label='CoreSet', linewidth=4)
plt.plot(train_set_size, lc, label='Least Conf.', linewidth=4)
plt.plot(train_set_size, margin, label='Margin', linewidth=4)
plt.legend()
plt.xlabel('Training Images')
plt.ylabel('Test Accuracy')
plt.title('MNIST DISTIL Implementation')
plt.savefig('MNIST_DISTIL.jpg')
